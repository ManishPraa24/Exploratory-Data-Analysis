# %% [markdown]
# <center>
#     <h1>
#         Exploratory Data Analysis - IT 462
#     </h1>
#     <br>
#     <h2>
#         Assignment - 1 : Missingno Package
#     </h2>
# </center>
#
#
#
# <h2>
#     Group No.: 17
# </h2>
#
# <h2>
#     Name: Manish Manojkumar Prajapati
# </h2>
# <h2>
#     Student-ID: 202411012
# </h2>

# %% [markdown]
# <h3>
#     1. Importing required libraries.
# </h3>

# %%
# Importing Libraries

import pandas as pd
import missingno as ms

url = r'https://raw.githubusercontent.com/ManishPraa24/Exploratory-Data-Analysis/main/Missingno/kamyr-digester.csv'

data = pd.read_csv(url)

data
# Out:
#     Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 0      31-00:00    23.10    16.520     121.717  1177.607      169.805
# 1      31-01:00    27.60    16.810      79.022  1328.360      341.327
# 2      31-02:00    23.19    16.709      79.562  1329.407      239.161
# 3      31-03:00    23.60    16.478      81.011  1334.877      213.527
# 4      31-04:00    22.90    15.618      93.244  1334.168      243.131
# ..          ...      ...       ...         ...       ...          ...
# 296    12-08:00    20.40    14.233      89.790  1278.006      379.458
# 297    12-09:00    20.90    15.167      84.640  1283.706      339.440
# 298    12-10:00    24.98       NaN      85.034  1278.345      368.564
# 299    12-11:00    21.00       NaN      88.013  1307.722      278.842
# 300    12-12:00    21.40       NaN      85.490  1255.986      273.484
#
#      T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# ...

# %% [markdown]
# <br>
# <h3>
#     2. Checking for overall missing values statistically.
# </h3>
# <br>

# %%
data.isnull().sum()
# Out:
# Observation          0
# Y-Kappa              0
# ChipRate             4
# BF-CMratio          14
# BlowFlow            13
# ChipLevel4           1
# T-upperExt-2         1
# T-lowerExt-2         1
# UCZAA               24
# WhiteFlow-4          1
# AAWhiteSt-4        141
# AA-Wood-4            1
# ChipMoisture-4       1
# SteamFlow-4          1
# Lower-HeatT-3        1
# Upper-HeatT-3        1
# ChipMass-4           1
# WeakLiquorF          1
# BlackFlow-2          1
# WeakWashF            1
# SteamHeatF-3         1
# T-Top-Chips-4        1
# SulphidityL-4      141
# dtype: int64

# %% [markdown]
# <br>
# <h3>
#     3. Plotting bar graph of missing values visualization.
# </h3>
# <br>

# %%
ms.bar(data)
# Out:
# <Axes: >

# %% [markdown]
# <br>
# <h2>
#     Observations:
# </h2>
# <h4>
# <ul>
#     <li>
#             Attributes 'AAWhiteSt-4' and 'SulphidityL-4' seems to have more missing values.
#     </li>
#     <li>
#             Attributes 'ChipRate', 'BF-CMratio', 'BlowFlow' and 'UCZAA' are having less missing values.
#     </li>
#     <li>
#             Attributes 'Observation' and 'Y-kappa' seems only attributes having no missing values.
#     </li>
#     <li>
#             Remaining Attributes are having atleast one value missing.
#     </li>
# </ul>
# </h4>
# <br>

# %% [markdown]
# <br>
# <h3>
#     4. Plotting the matrix plot.
# </h3>
# <br>

# %%
ms.matrix(data)
# Out:
# <Axes: >

# %% [markdown]
# <br>
# <h2>
#     Observations:
# </h2>
# <h4>
#     <ul>
#         <li>
#             Attributes 'AAWhiteSt-4' and 'SulphidityL-4' seems to have similar distribution of the missing values.
#         </li>
#         <li>
#             Attributes from 'AA-Wood-4' to 'T-Top-Chips-4' are having missing values almost at same tuple.
#         </li>
#         <li>
#             'BF-CMratio' and 'BlowFlow' are having missing values simultaneously.
#         </li>
#     </ul>
# </h4>

# %% [markdown]
# <br>
# <h3>
#     5. Plotting the HeatMap.
# </h3>

# %%
ms.heatmap(data)
# Out:
# <Axes: >

# %% [markdown]
# <br>
# <h3>
#     6. Plotting Dendrogram.
# </h3>

# %%
ms.dendrogram(data)
# Out:
# <Axes: >

# %% [markdown]
# <br>
# <h2>
#     From above visualizations, missingno package is very much useful for identifying the patterns in missing values among different features, and also enable us to get the correlation among the missing values.
# </h2>
